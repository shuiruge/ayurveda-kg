# %%
from typing import Union


class Entity:
    
    def __init__(self, name: str):
        self.name = name.replace(' ', '_')

    def __eq__(self, other):
        return self.name == other.name

    def __hash__(self):
        return hash(self.name)

    def __repr__(self):
        return f'{self.name}'


class Relation:

    def __init__(self, name: str):
        self.name = name.replace(' ', '_')

    def __eq__(self, other):
        return self.name == other.name

    def __hash__(self):
        return hash(self.name)

    def __repr__(self):
        return self.name


class Fact:

    def __init__(self,
                 head: Union[Entity, str],
                 relation: Union[Relation, str],
                 tail: Union[Entity, str]):
        if isinstance(head, str):
            head = Entity(head)
        self.head = head

        if isinstance(relation, str):
            relation = Relation(relation)
        self.relation = relation

        if isinstance(tail, str):
            tail = Entity(tail)
        self.tail = tail

    def __repr__(self):
        return f'{repr(self.head)} -- {repr(self.relation)} --> {repr(self.tail)}'


class KnowledgeGraph:
    """The elemental data structure of knowledge graph.
    
    Based on ref[1], section II.B, knowledge graph is defined as
    triplet (E, R, F), where E for entities, R for relations, and
    F for facts. Fact is defined as triplet (h, r, t), where head
    h and tail t are in E and relation r in R.

    References
    ----------
    1. [A Survey on Knowledge Graphs: Representation, Acquisition and Applications](https://arxiv.org/abs/2002.00388v4).
    """
    
    def __init__(self,
                 entities: set = None,
                 relations: set = None,
                 facts: set = None):
        self.entities = set() if entities is None else entities
        self.relations = set() if relations is None else relations
        self.facts = set() if facts is None else facts

    def add(self, fact: Fact):
        self.entities.add(fact.head)
        self.relations.add(fact.relation)
        self.entities.add(fact.tail)
        self.facts.add(fact)

    def __iadd__(self, other):
        self.entities.update(other.entities)
        self.relations.update(other.relations)
        self.facts.update(other.facts)
        return self

# %%
import os
import json


SUBCATEGORY_RELATION = 'is_of'


def update_knowledge_graph(kg: KnowledgeGraph,
                           data_path: str,
                           category: str = None):
    """Inplace update the knowledge graph `kg` by the data in the
    path `data_path`.

    Parameters
    ----------
    data_path: The path to the JSON file of the pre-structured data.
        We store the data in a specific JSON format, wherein the keys
        are the heads, and values are also JSON, but with the keys
        relations and the values tails or list of tails.

        For example, in "data/taste.json",
        
            {
                "sweet": {
                    "component": [
                        "earth",
                        "water"
                    ]
                },
                "sour": {
                    "component": [
                        "earth",
                        "fire"
                    ]
                },
                ...
            }

    kg: The base knowledge graph, on which new data are added.
    """
    with open(data_path, 'r') as f:
        heads = json.load(f)

    for head, relations in heads.items():
        kg.entities.add(Entity(head))
        kg.facts.add(Fact(head, SUBCATEGORY_RELATION, category))
        for relation, tails in relations.items():
            kg.relations.add(Relation(relation))
            tails = [tails] if isinstance(tails, str) else tails
            for tail in tails:
                kg.entities.add(Entity(tail))
                fact = Fact(head, relation, tail)
                kg.facts.add(fact)


def _load_data_recur(data_dir_path: str,
                     kg: KnowledgeGraph = None):
    if kg is None:
        kg = KnowledgeGraph()
        category = None
    else:
        _, category = os.path.split(data_dir_path)

    for filename in os.listdir(data_dir_path):
        file_path = os.path.join(data_dir_path, filename)

        if os.path.isdir(file_path):
            kg = _load_data_recur(file_path, kg)

        else:
            subcategory, ext = os.path.splitext(filename)
            assert ext == '.json'
            if category is not None:
                kg.add(Fact(subcategory, SUBCATEGORY_RELATION, category))
            update_knowledge_graph(kg, file_path, subcategory)
    return kg


def load_data(data_dir_path: str):
    return _load_data_recur(data_dir_path, None)

# %%
kg = load_data('../data')
for fact in kg.facts:
    print(fact)
# Out:
# cravings_for_sweet_and_cold_food_and_drink -- is_of --> others
# cold -- is_of --> attribute
# lack_of_inner_drive_and_mental_clarity -- hints_for_elevation --> kapha
# strong_intolerance_for_heat -- hints_for_elevation --> pitta
# susceptibility_to_colds_with_productive_cough -- hints_for_elevation --> kapha
# light -- creates --> alertness
# hard -- is_of --> attribute
# sweet -- has_component --> earth
# pungent -- has_component --> fire
# cravings_for_sweet_and_cold_food_and_drink -- hints_for_elevation --> pitta
# hot -- is_of --> attribute
# strong_attachment_to_things -- is_of --> mental
# burning_sensations_(especially_in_the_eyes) -- is_of --> others
# slow -- is_of --> attribute
# pitta -- has_function --> thirst
# beef -- is_of --> meat
# sweet -- has_component --> water
# bitter -- is_of --> taste
# static -- is_of --> attribute
# heart_burn -- is_of --> others
# oily -- is_of --> attribute
# urine_is_blackish-brown -- is_of --> urine
# strong_attachment_to_things -- hints_for_elevation --> kapha
# burning_sensations_(especially_in_the_eyes) -- hints_for_elevation --> pitta
# slow -- elevates --> kapha
# pitta -- has_function --> anger
# sour -- is_of --> taste
# astringent -- is_of --> taste
# bitter -- has_component --> ether
# pitta -- has_component --> fire
# mobile -- is_of --> attribute
# beef -- taste --> sweet
# heart_burn -- hints_for_elevation --> pitta
# urine_is_blackish-brown -- hints_for_elevation --> vata
# dry -- is_of --> attribute
# excessive_thirst_or_hunger -- is_of --> others
# slow -- pacifies --> vata
# sour -- has_component --> earth
# bitter -- has_component --> air
# urine -- is_of --> diagnosis
# subtle -- is_of --> attribute
# pitta -- is_of --> dosha
# sleeplessness -- is_of --> others
# loss_of_appetite_and_hunger -- is_of --> others
# urine_is_dark_yellow_(even_with_enough_intake_water) -- is_of --> urine
# slow -- pacifies --> pitta
# beef -- heating_or_cooling --> heating
# excessive_thirst_or_hunger -- hints_for_elevation --> pitta
# slimy -- is_of --> attribute
# sour -- has_component --> fire
# sleeplessness -- hints_for_elevation --> vata
# loss_of_appetite_and_hunger -- hints_for_elevation --> kapha
# gross -- is_of --> attribute
# urine_is_dark_yellow_(even_with_enough_intake_water) -- hints_for_elevation --> pitta
# heavy -- is_of --> attribute
# vata -- has_function --> fear
# loose -- is_of --> others
# astringent -- has_component --> earth
# beef -- postdigestive_taste --> sweet
# salty -- is_of --> taste
# slow -- creates --> sluggishness
# rough -- is_of --> attribute
# pitta -- has_function --> self-confidence
# sensitivity_(such_as_to_noise_and_touch) -- hints_for_elevation --> vata
# pitta -- has_function --> intelligence
# strong_intolerance_to_cold -- is_of --> others
# reduced_sense_of_taste_and_smell -- is_of --> others
# pitta -- has_function --> hate
# cloudy -- is_of --> attribute
# vata -- has_function --> emptiness
# urine_is_cloudy -- is_of --> urine
# astringent -- has_component --> air
# vata -- has_component --> air
# loose -- hints_for_elevation --> pitta
# pungent -- is_of --> taste
# salty -- has_component --> water
# slow -- creates --> relaxation
# dense -- is_of --> attribute
# beef -- has_attribute --> heavy
# strong_intolerance_to_cold -- hints_for_elevation --> vata
# reduced_sense_of_taste_and_smell -- hints_for_elevation --> kapha
# pulse -- is_of --> diagnosis
# urine_is_cloudy -- hints_for_elevation --> kapha
# clear -- is_of --> attribute
# increased_sweating -- is_of --> others
# salty -- has_component --> fire
# slow -- creates --> dullness
# liquid -- is_of --> attribute
# vata -- has_function --> supporting_memory
# beef -- has_attribute --> thick
# restlessness_and_inability_to_sit_still -- is_of --> others
# feeling_heavy_and_sluggish -- is_of --> others
# heavy -- elevates --> kapha
# vata -- has_function --> igniting_agni
# vata -- has_function --> anxiety
# increased_sweating -- hints_for_elevation --> pitta
# sharp -- is_of --> attribute
# skin -- is_of --> diagnosis
# soft -- is_of --> attribute
# pitta -- has_component --> water
# heavy -- pacifies --> vata
# beef -- elevates --> pitta
# restlessness_and_inability_to_sit_still -- hints_for_elevation --> vata
# feeling_heavy_and_sluggish -- hints_for_elevation --> kapha
# pulse_is_quick_and_changes_speed,_like_a_winding_snake -- is_of --> pulse
# pungent -- has_component --> air
# kapha -- has_function --> lubricating_joints
# tongue_is_deep_red_or_yellowish -- hints_for_elevation --> pitta
# pitta -- has_function --> temperature
# ring_finger_feels_the_pulse_throbbing_more_strongly -- is_of --> pulse
# heavy -- pacifies --> pitta
# beef -- elevates --> kapha
# lamb -- taste --> sweet
# eyes_blink_frequently -- hints_for_elevation --> vata
# pitta -- has_function --> jealous
# fish -- is_of --> meat
# exhaustion -- is_of --> mental
# vata -- has_function --> secretions
# muscular_tension -- is_of --> others
# fatigue_and_lethargy -- is_of --> others
# pitta -- has_function --> hunger
# pulse_is_quick_and_changes_speed,_like_a_winding_snake -- hints_for_elevation --> vata
# white_coating_on_the_tongue -- is_of --> tongue
# lamb -- taste --> astringent
# vata -- has_function --> transformation_of_tissue
# ring_finger_feels_the_pulse_throbbing_more_strongly -- hints_for_elevation --> kapha
# pitta -- has_function --> providing_blood
# eyes_are_yellowish_and_sensitive_to_bright_light -- is_of --> eyes
# light -- is_of --> attribute
# beef -- pacifies --> vata
# fish -- taste --> sweet
# exhaustion -- hints_for_elevation --> vata
# muscular_tension -- hints_for_elevation --> vata
# fatigue_and_lethargy -- hints_for_elevation --> kapha
# index_finger_feels_the_pulse_throbbing_more_strongly -- is_of --> pulse
# kapha -- has_function --> accumulation
# heavy -- creates --> dullness
# vata -- has_function --> natural_urges
# white_coating_on_the_tongue -- hints_for_elevation --> kapha
# lamb -- heating_or_cooling --> heating
# fish -- heating_or_cooling --> heating
# eyes_are_yellowish_and_sensitive_to_bright_light -- hints_for_elevation --> pitta
# pitta -- has_function --> coloring_skin
# kapha -- has_function --> forgiveness
# chicken -- is_of --> meat
# irritation_or_a_short_temper -- is_of --> mental
# constipation -- is_of --> others
# difficulty_becoming_active -- is_of --> others
# index_finger_feels_the_pulse_throbbing_more_strongly -- hints_for_elevation --> vata
# heavy -- creates --> lethargy
# vata -- has_function --> excretion
# sweet -- is_of --> taste
# lamb -- postdigestive_taste --> sweet
# skin_is_dry,_cracked,_and_rough -- is_of --> skin
# fish -- postdigestive_taste --> sweet
# eyes_are_watering_and_dull -- is_of --> eyes
# others -- is_of --> diagnosis
# kapha -- is_of --> dosha
# chicken -- taste --> sweet
# irritation_or_a_short_temper -- hints_for_elevation --> pitta
# constipation -- hints_for_elevation --> vata
# difficulty_becoming_active -- hints_for_elevation --> kapha
# pulse_is_strong,_like_the_movement_of_a_jumping_frog -- is_of --> pulse
# meat -- is_of --> food
# lack_of_concentration -- is_of --> mental
# lamb -- has_attribute --> heavy
# vata -- has_function --> breathing
# fish -- has_attribute --> heavy
# pitta -- has_function --> body_heat
# skin_is_dry,_cracked,_and_rough -- hints_for_elevation --> vata
# kapha -- has_function --> greed
# eyes_are_watering_and_dull -- hints_for_elevation --> kapha
# pitta -- has_function --> digestion
# prone_to_judge_others_and_themselves -- is_of --> mental
# cravings_for_sweet,_salty,_or_sour_food -- is_of --> others
# pitta -- has_function --> fueling_agni
# chicken -- taste --> astringent
# oily_scalp_and_dandruff -- is_of --> others
# pulse_is_strong,_like_the_movement_of_a_jumping_frog -- hints_for_elevation --> pitta
# light -- elevates --> vata
# lamb -- elevates --> vata
# lack_of_concentration -- hints_for_elevation --> vata
# vata -- has_function --> movement
# fish -- has_attribute --> oily
# skin_is_red,_excessively_hot,_or_sensitive_with_rashes -- is_of --> skin
# vata -- is_of --> dosha
# light -- elevates --> pitta
# chicken -- heating_or_cooling --> heating
# prone_to_judge_others_and_themselves -- hints_for_elevation --> pitta
# cravings_for_sweet,_salty,_or_sour_food -- hints_for_elevation --> vata
# oily_scalp_and_dandruff -- hints_for_elevation --> kapha
# middle_finger_feels_the_pulse_throbbing_more_strongly -- is_of --> pulse
# lamb -- elevates --> pitta
# mental -- is_of --> diagnosis
# sleeplessness -- is_of --> mental
# fish -- elevates --> pitta
# eyes -- is_of --> diagnosis
# kapha -- has_component --> water
# skin_is_red,_excessively_hot,_or_sensitive_with_rashes -- hints_for_elevation --> pitta
# vata -- has_component --> ether
# tongue_is_brown-to-black -- is_of --> tongue
# overly_competitive_behavior -- is_of --> mental
# stiffness_or_pain_in_the_joints -- is_of --> others
# sinusitis_or_blocked_sinuses -- is_of --> others
# chicken -- postdigestive_taste --> pungent
# lamb -- elevates --> kapha
# middle_finger_feels_the_pulse_throbbing_more_strongly -- hints_for_elevation --> pitta
# light -- elevates --> agni
# fish -- elevates --> kapha
# sleeplessness -- hints_for_elevation --> vata
# kapha -- has_component --> earth
# skin_is_pale,_excessively_cold,_or_clammy -- is_of --> skin
# tongue_is_brown-to-black -- hints_for_elevation --> vata
# vata -- has_function --> motor_functions
# light -- pacifies --> kapha
# overly_competitive_behavior -- hints_for_elevation --> pitta
# stiffness_or_pain_in_the_joints -- hints_for_elevation --> vata
# sinusitis_or_blocked_sinuses -- hints_for_elevation --> kapha
# pulse_is_slow_and_broad,_like_the_stately_movement_of_a_swan -- is_of --> pulse
# vata -- has_function --> sensory_functions
# chicken -- has_attribute --> light
# fish -- pacifies --> vata
# sensitivity_(such_as_to_noise_and_touch) -- is_of --> mental
# kapha -- has_function --> attachment
# tongue -- is_of --> diagnosis
# skin_is_pale,_excessively_cold,_or_clammy -- hints_for_elevation --> kapha
# kapha -- has_function --> moisturizing_food
# tongue_is_deep_red_or_yellowish -- is_of --> tongue
# eyes_blink_frequently -- is_of --> eyes
# lack_of_inner_drive_and_mental_clarity -- is_of --> mental
# strong_intolerance_for_heat -- is_of --> others
# susceptibility_to_colds_with_productive_cough -- is_of --> others
# pulse_is_slow_and_broad,_like_the_stately_movement_of_a_swan -- hints_for_elevation --> kapha
# light -- creates --> freshness
# lamb -- is_of --> meat
# chicken -- has_attribute --> oily
