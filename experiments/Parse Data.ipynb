# %%
from typing import Union


class KnowledgeGraph:
    """The elemental data structure of knowledge graph.
    
    Based on ref[1], section II.B, knowledge graph is defined as
    triplet (E, R, F), where E for entities, R for relations, and
    F for facts. Fact is defined as triplet (h, r, t), where head
    h and tail t are in E and relation r in R.

    References
    ----------
    1. [A Survey on Knowledge Graphs: Representation, Acquisition and Applications](https://arxiv.org/abs/2002.00388v4).
    """
    
    def __init__(self,
                 entities: set = None,
                 relations: set = None,
                 facts: set = None):
        self.entities = set() if entities is None else entities
        self.relations = set() if relations is None else relations
        self.facts = set() if facts is None else facts

    def __iadd__(self, other):
        self.entities.update(other.entities)
        self.relations.update(other.relations)
        self.facts.update(other.facts)
        return self


class Entity:
    
    def __init__(self, name: str):
        self.name = name.replace(' ', '_')

    def __eq__(self, other):
        return self.name == other.name

    def __hash__(self):
        return hash(self.name)

    def __repr__(self):
        return f'{self.name}'


class Relation:

    def __init__(self, name: str):
        self.name = name.replace(' ', '_')

    def __eq__(self, other):
        return self.name == other.name

    def __hash__(self):
        return hash(self.name)

    def __repr__(self):
        return self.name


class Fact:

    def __init__(self,
                 head: Union[Entity, str],
                 relation: Union[Relation, str],
                 tail: Union[Entity, str]):
        if isinstance(head, str):
            head = Entity(head)
        self.head = head

        if isinstance(relation, str):
            relation = Relation(relation)
        self.relation = relation

        if isinstance(tail, str):
            tail = Entity(tail)
        self.tail = tail

    def __repr__(self):
        return f'{repr(self.head)} -- {repr(self.relation)} --> {repr(self.tail)}'

# %%
import os
import json


SUBCATEGORY_RELATION = 'is_of'


def update_knowledge_graph(kg: KnowledgeGraph,
                           data_path: str,
                           category: str = None):
    """Inplace update the knowledge graph `kg` by the data in the
    path `data_path`.

    Parameters
    ----------
    data_path: The path to the JSON file of the pre-structured data.
        We store the data in a specific JSON format, wherein the keys
        are the heads, and values are also JSON, but with the keys
        relations and the values tails or list of tails.

        For example, in "data/taste.json",
        
            {
                "sweet": {
                    "component": [
                        "earth",
                        "water"
                    ]
                },
                "sour": {
                    "component": [
                        "earth",
                        "fire"
                    ]
                },
                ...
            }

    kg: The base knowledge graph, on which new data are added.
    """
    with open(data_path, 'r') as f:
        heads = json.load(f)

    for head, relations in heads.items():
        kg.entities.add(Entity(head))
        kg.facts.add(Fact(head, SUBCATEGORY_RELATION, category))
        for relation, tails in relations.items():
            kg.relations.add(Relation(relation))
            tails = [tails] if isinstance(tails, str) else tails
            for tail in tails:
                kg.entities.add(Entity(tail))
                fact = Fact(head, relation, tail)
                kg.facts.add(fact)


def _load_data_recur(data_dir_path: str,
                     kg: KnowledgeGraph = None):
    if kg is None:
        kg = KnowledgeGraph()
        category = None
    else:
        _, category = os.path.split(data_dir_path)

    for filename in os.listdir(data_dir_path):
        file_path = os.path.join(data_dir_path, filename)
        if os.path.isdir(file_path):
            continue

        subcategory, ext = os.path.splitext(filename)
        assert ext == '.json'

        if category is not None:
            kg.add(Fact(subcategory, SUBCATEGORY_RELATION, category))

        update_knowledge_graph(kg, file_path, subcategory)
    return kg


def load_data(data_dir_path: str):
    return _load_data_recur(data_dir_path, None)

# %%
kg = load_data('../data')
for fact in kg.facts:
    print(fact)
# Out:
# rough -- is_of --> attribute
# astringent -- component --> air
# light -- elevate --> pitta
# kapha -- elevated --> blocked_sinuses
# pitta -- function --> digestion
# vata -- function --> breathing
# salty -- component --> fire
# slow -- create --> relaxation
# pitta -- function --> temperature
# heavy -- is_of --> attribute
# dense -- is_of --> attribute
# light -- elevate --> agni
# pulse -- is_of --> diagnosis
# vata -- elevated --> exhaustion
# kapha -- elevated --> colds_with_productive_cough
# pitta -- function --> hunger
# slow -- create --> dullness
# vata -- component --> air
# pungent -- is_of --> taste
# light -- pacify --> kapha
# pitta -- function --> body_heat
# liquid -- is_of --> attribute
# vata -- elevated --> cravings_for_sweet,_salty,_or_sour_food
# heavy -- elevate --> kapha
# sweet -- is_of --> taste
# vata -- elevated --> strong_intolerance_to_cold
# sharp -- is_of --> attribute
# pitta -- function --> thirst
# pungent -- component --> air
# light -- create --> freshness
# soft -- is_of --> attribute
# sweet -- component --> earth
# heavy -- pacify --> vata
# vata -- elevated --> muscular_tension
# vata -- elevated --> stiffness_or_pain_in_the_joints
# pungent -- component --> fire
# cold -- is_of --> attribute
# pitta -- function --> intelligence
# sweet -- component --> water
# heavy -- pacify --> pitta
# light -- create --> alertness
# hard -- is_of --> attribute
# pitta -- is_of --> dosha
# vata -- is_of --> dosha
# bitter -- is_of --> taste
# hot -- is_of --> attribute
# pitta -- function --> self-confidence
# vata -- elevated --> restlessness
# sour -- is_of --> taste
# slow -- is_of --> attribute
# static -- is_of --> attribute
# bitter -- component --> ether
# heavy -- create --> dullness
# pitta -- component --> fire
# vata -- component --> ether
# oily -- is_of --> attribute
# pitta -- function --> anger
# sour -- component --> earth
# slow -- elevate --> kapha
# bitter -- component --> air
# heavy -- create --> lethargy
# mobile -- is_of --> attribute
# dry -- is_of --> attribute
# pitta -- function --> hate
# sour -- component --> fire
# slow -- pacify --> vata
# pitta -- component --> water
# astringent -- is_of --> taste
# light -- is_of --> attribute
# subtle -- is_of --> attribute
# slow -- pacify --> pitta
# salty -- is_of --> taste
# slimy -- is_of --> attribute
# pitta -- function --> jealous
# vata -- function --> movement
# astringent -- component --> earth
# light -- elevate --> vata
# gross -- is_of --> attribute
# slow -- create --> sluggishness
# vata -- elevated --> constipation
# salty -- component --> water
# pitta -- function --> fueling_agni
# kapha -- component --> earth
# vata -- function --> emptiness
# cloudy -- is_of --> attribute
# pitta -- elevated --> sensitivity_to_bright_light
# kapha -- elevated --> excessively_cold_skin
# pitta -- function --> providing_blood
# kapha -- function --> moisturizing_food
# vata -- function --> fear
# clear -- is_of --> attribute
# pitta -- elevated --> excessive_thirst_or_hunger
# kapha -- elevated --> loss_of_appetite
# pitta -- function --> coloring_skin
# kapha -- function --> lubricating_joints
# vata -- function --> anxiety
# vata -- function --> excretion
# pitta -- elevated --> loose
# kapha -- elevated --> reduced_sense_of_taste_and_smell
# vata -- function --> natural_urges
# pitta -- elevated --> irritation
# kapha -- function --> forgiveness
# pitta -- elevated --> more_sweating
# kapha -- elevated --> weight_gain
# vata -- function --> supporting_memory
# kapha -- function --> greed
# pitta -- elevated --> prone_to_judge
# vata -- function --> transformation_of_tissue
# pitta -- elevated --> cravings_for_sweet_and_cold_food
# kapha -- elevated --> heaviness
# vata -- function --> secretions
# pitta -- elevated --> overly_competitive_behavior
# kapha -- function --> attachment
# vata -- function --> igniting_agni
# pitta -- elevated --> heart_burn
# kapha -- elevated --> sluggishness
# pitta -- elevated --> strong_intolerance_for_heat
# kapha -- function --> accumulation
# vata -- elevated --> sensitivity
# pitta -- elevated --> red_face
# vata -- function --> sensory_functions
# kapha -- is_of --> dosha
# kapha -- elevated --> lethargy
# vata -- elevated --> sleeplessness
# pitta -- elevated --> burning_sensations_(especially_in_the_eyes)
# kapha -- elevated --> lack_of_mental_clarity
# kapha -- component --> water
# vata -- function --> motor_functions
# kapha -- elevated --> oily_scalp_and_dandruff
# kapha -- elevated --> strong_attachment
# vata -- elevated --> lack_of_concentration
